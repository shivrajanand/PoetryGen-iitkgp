# %%
import pandas as pd

# %%
zero_shot = pd.read_csv("/nlsasfs/home/dibd/dibd-unified/iitkgp/jeetk/SHIVRAJ/PoetryGen-iitkgp/Generate-Poetry/phi4-test-zs-hin-anustubh_metrics.csv")
three_shot = pd.read_csv("/nlsasfs/home/dibd/dibd-unified/iitkgp/jeetk/SHIVRAJ/PoetryGen-iitkgp/Generate-Poetry/phi4-test-3shot-hin-anustubh_metrics.csv")

# %%
zero_shot.columns,three_shot.columns
# Out:
# (Index(['Shlok', 'meaning', 'prompt', 'chanda', 'model-out',
#         'full_anustubh_percent', 'half_anustubh_percent',
#         'semantic_similarity_percent'],
#        dtype='object'),
#  Index(['Shlok', 'meaning', 'prompt', 'chanda', 'model-out',
#         'full_anustubh_percent', 'half_anustubh_percent',
#         'semantic_similarity_percent'],
#        dtype='object'))

# %%
zero_shot[['full_anustubh_percent', 'half_anustubh_percent', 'semantic_similarity_percent']].mean()
# Out:
# full_anustubh_percent           1.146497
# half_anustubh_percent           2.675159
# semantic_similarity_percent    75.612780
# dtype: float64

# %%
three_shot[['full_anustubh_percent', 'half_anustubh_percent', 'semantic_similarity_percent']].mean()
# Out:
# full_anustubh_percent          40.254777
# half_anustubh_percent          21.528662
# semantic_similarity_percent    71.909619
# dtype: float64
